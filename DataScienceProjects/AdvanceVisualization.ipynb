# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
movie_stats=pd.read_csv('F:\\Python Learning\\MovieRating.csv')

# %%
movie_stats.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
vis1=sn.lmplot(data=movie_stats,x='Rotten Tomatoes Ratings %',y='Audience Ratings %',fit_reg=False,hue='Genre')

# %%
movie_stats.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movie_stats.columns=['Film','Genre','CriticsRatings','AudienceRatings','Budget_Millions','Year']

# %%
movie_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    object
#  1   Genre            559 non-null    object
#  2   CriticsRatings   559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   Budget_Millions  559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movie_stats.describe()
# Out:
#        CriticsRatings  AudienceRatings  Budget_Millions         Year
# count      559.000000       559.000000       559.000000   559.000000
# mean        47.309481        58.744186        50.236136  2009.152057
# std         26.413091        16.826887        48.731817     1.362632
# min          0.000000         0.000000         0.000000  2007.000000
# 25%         25.000000        47.000000        20.000000  2008.000000
# 50%         46.000000        58.000000        35.000000  2009.000000
# 75%         70.000000        72.000000        65.000000  2010.000000
# max         97.000000        96.000000       300.000000  2011.000000

# %%
movie_stats[['Film','Genre']]
# Out:
#                       Film      Genre
# 0    (500) Days of Summer      Comedy
# 1              10,000 B.C.  Adventure
# 2               12 Rounds      Action
# 3                127 Hours  Adventure
# 4                17 Again      Comedy
# ..                     ...        ...
# 554          Your Highness     Comedy
# 555        Youth in Revolt     Comedy
# 556                 Zodiac   Thriller
# 557            Zombieland      Action
# 558              Zookeeper     Comedy
#
# [559 rows x 2 columns]

# %%
len(movie_stats)
# Out:
# 559

# %%
import os

# %%
os.getcwd()
# Out:
# 'F:\\Python Learning'

# %%
movie_stats.head()
# Out:
#                     Film      Genre  CriticsRatings  AudienceRatings  \
# 0  (500) Days of Summer      Comedy              87               81
# 1            10,000 B.C.  Adventure               9               44
# 2             12 Rounds      Action              30               52
# 3              127 Hours  Adventure              93               84
# 4              17 Again      Comedy              55               70
#
#    Budget_Millions  Year
# 0                8  2009
# 1              105  2008
# 2               20  2009
# 3               18  2010
# 4               20  2009

# %%
#Category Data Type conversion
movie_stats.Film=movie_stats.Film.astype('category')

# %%
movie_stats.head()
# Out:
#                     Film      Genre  CriticsRatings  AudienceRatings  \
# 0  (500) Days of Summer      Comedy              87               81
# 1            10,000 B.C.  Adventure               9               44
# 2             12 Rounds      Action              30               52
# 3              127 Hours  Adventure              93               84
# 4              17 Again      Comedy              55               70
#
#    Budget_Millions  Year
# 0                8  2009
# 1              105  2008
# 2               20  2009
# 3               18  2010
# 4               20  2009

# %%
movie_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    object
#  2   CriticsRatings   559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   Budget_Millions  559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 47.4+ KB

# %%
movie_stats.Genre=movie_stats.Genre.astype('category')
movie_stats.Year=movie_stats.Year.astype('category')

# %%
movie_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    category
#  2   CriticsRatings   559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   Budget_Millions  559 non-null    int64
#  5   Year             559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
movie_stats.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movie_stats.Film.cat.categories
# Out:
# Index(['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours',
#        '17 Again ', '2012', '27 Dresses', '30 Days of Night',
#        '30 Minutes or Less', '50/50',
#        ...
#        'Yes Man', 'Yogi Bear', 'You Again', 'You Don't Mess with the Zohan',
#        'You Will Meet a Tall Dark Stranger', 'Your Highness',
#        'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper'],
#       dtype='object', length=559)

# %%
movie_stats.Year.cat.categories
# Out:
# Int64Index([2007, 2008, 2009, 2010, 2011], dtype='int64')

# %%
movie_stats[['Film','Genre','Year']]
# Out:
#                       Film      Genre  Year
# 0    (500) Days of Summer      Comedy  2009
# 1              10,000 B.C.  Adventure  2008
# 2               12 Rounds      Action  2009
# 3                127 Hours  Adventure  2010
# 4                17 Again      Comedy  2009
# ..                     ...        ...   ...
# 554          Your Highness     Comedy  2011
# 555        Youth in Revolt     Comedy  2009
# 556                 Zodiac   Thriller  2007
# 557            Zombieland      Action  2009
# 558              Zookeeper     Comedy  2011
#
# [559 rows x 3 columns]

# %%
movie_stats.describe()
# Out:
#        CriticsRatings  AudienceRatings  Budget_Millions
# count      559.000000       559.000000       559.000000
# mean        47.309481        58.744186        50.236136
# std         26.413091        16.826887        48.731817
# min          0.000000         0.000000         0.000000
# 25%         25.000000        47.000000        20.000000
# 50%         46.000000        58.000000        35.000000
# 75%         70.000000        72.000000        65.000000
# max         97.000000        96.000000       300.000000

# %%
#jointplots

# %%
sn.set_style('darkgrid')
j=sn.jointplot(data=movie_stats,x='CriticsRatings',y='AudienceRatings',color='blue',kind="hex")

# %%
sn.set_style('darkgrid')
j2=sn.jointplot(data=movie_stats,x='AudienceRatings',y='Budget_Millions',kind="resid",color='darkred')

# %%
movie_stats[['Film','Budget_Millions','Year']].max()
# Out:
# Film               Zookeeper
# Budget_Millions          300
# Year                    2011
# dtype: object

# %%
movie_stats[['Film','Budget_Millions','Year']].min()
# Out:
# Film               (500) Days of Summer
# Budget_Millions                        0
# Year                                2007
# dtype: object

# %%
j=sn.jointplot(data=movie_stats,x="CriticsRatings",y="Budget_Millions",kind="kde",color="maroon")

# %% [markdown]
# ---

# %%
#old method
sn.set_style('darkgrid')
m1=sn.distplot(movie_stats.AudienceRatings,bins=15,color='Green',)
plt.rcParams['figure.figsize']=[15,12]

# %%
sn.set_style('darkgrid')
m2=sn.distplot(movie_stats.CriticsRatings,bins=15,color='orange')

# %%
#Histogram

# %%
sn.set_style('white')
n1=plt.hist(movie_stats.AudienceRatings,bins=15)

# %%
sn.set_style("darkgrid")
n2=plt.hist(movie_stats.CriticsRatings,bins=15)

# %%
n3=plt.hist(movie_stats.Genre,bins=15)

# %%
n4=plt.hist(movie_stats.Budget_Millions,bins=15)

# %%
#Stacked Histogram

# %%
movie_stats[movie_stats.Genre=="Drama"]
# Out:
#                     Film  Genre  CriticsRatings  AudienceRatings  \
# 10            88 Minutes  Drama               5               51
# 11    A Dangerous Method  Drama              79               89
# 13        A Serious Man   Drama              89               64
# 18          Albert Nobbs  Drama              53               43
# 23       All Good Things  Drama              33               64
# ..                   ...    ...             ...              ...
# 529            War Horse  Drama              77               73
# 532  Water For Elephants  Drama              60               72
# 534     We Own the Night  Drama              55               63
# 541             Whip It   Drama              84               73
# 545        Winter's Bone  Drama              94               73
#
#      Budget_Millions  Year
# 10                30  2007
# 11                20  2011
# 13                 7  2009
# 18                 8  2011
# 23                20  2010
# ...

# %%
movie_stats[movie_stats.Genre=="Drama"].Budget_Millions
# Out:
# 10     30
# 11     20
# 13      7
# 18      8
# 23     20
#        ..
# 529    66
# 532    38
# 534    21
# 541    15
# 545     2
# Name: Budget_Millions, Length: 101, dtype: int64

# %%
plt.hist(movie_stats[movie_stats.Genre=="Action"].Budget_Millions,bins=15)
plt.hist(movie_stats[movie_stats.Genre=="Adventure"].Budget_Millions,bins=15)
plt.hist(movie_stats[movie_stats.Genre=="Comedy"].Budget_Millions,bins=15)
plt.hist(movie_stats[movie_stats.Genre=="Romance"].Budget_Millions,bins=15)
plt.hist(movie_stats[movie_stats.Genre=="Thriller"].Budget_Millions,bins=15)
plt.hist(movie_stats[movie_stats.Genre=="Drama"].Budget_Millions,bins=15)
plt.show()

# %%
movie_stats.Genre
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: category
# Categories (7, object): [Action, Adventure, Comedy, Drama, Horror, Romance, Thriller]

# %%
mylist=[movie_stats[movie_stats.Genre=="Action"].Budget_Millions,\
        movie_stats[movie_stats.Genre=="Adventure"].Budget_Millions,\
        movie_stats[movie_stats.Genre=="Comedy"].Budget_Millions,\
        movie_stats[movie_stats.Genre=="Romance"].Budget_Millions,\
        movie_stats[movie_stats.Genre=="Thriller"].Budget_Millions,\
        movie_stats[movie_stats.Genre=="Horror"].Budget_Millions,\
        movie_stats[movie_stats.Genre=="Drama"].Budget_Millions]

# %%
plt.hist(mylist,bins=15,stacked=True)
plt.legend(labels=movie_stats.Genre,loc='upper left',bbox_to_anchor=[1,1])
plt.show()

# %%
for gen in movie_stats.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
list1=list()
mylabel=list()
for gen in movie_stats.Genre.cat.categories:
    list1.append(movie_stats[movie_stats.Genre==gen].Budget_Millions)
    mylabel.append(gen)
h1=plt.hist(list1,bins=30,stacked=True,rwidth=2,label=mylabel)
plt.legend(loc='upper left',bbox_to_anchor=[1,1],prop={'size':15})
plt.rcParams["figure.figsize"] = [13,9]
plt.rcParams.update({'font.size': 12})
plt.show()

# %%
#KDE plot
t1=sn.lmplot(data=movie_stats,x='AudienceRatings',y='CriticsRatings',fit_reg=False,hue='Year',size=7)

# %%
t2=sn.kdeplot(movie_stats.AudienceRatings,movie_stats.CriticsRatings,shade=True,shade_lowest=False,cmap='Reds')

# %%
t2=sn.kdeplot(movie_stats.AudienceRatings,movie_stats.CriticsRatings,shade=True,shade_lowest=False,cmap='Reds')
t3=sn.kdeplot(movie_stats.AudienceRatings,movie_stats.CriticsRatings,cmap='Reds')

# %% [markdown]
# ---

# %%
sn.set_style("dark")
k4=sn.kdeplot(movie_stats.Budget_Millions,movie_stats.AudienceRatings)

# %%
sn.set_style("dark")
k4=sn.kdeplot(movie_stats.Budget_Millions,movie_stats.CriticsRatings)

# %%
f,ax=plt.subplots(1,2,figsize=(15,9),sharex=True,sharey=True)
k4=sn.kdeplot(movie_stats.Budget_Millions,movie_stats.AudienceRatings,ax=ax[0])
k5=sn.kdeplot(movie_stats.Budget_Millions,movie_stats.CriticsRatings,ax=ax[1])
k4.set(xlim=(-20,160))
plt.show()

# %%
f,ax=plt.subplots(2,2)
k4=sn.kdeplot(movie_stats.Budget_Millions,movie_stats.AudienceRatings,ax=ax[0,0])
k5=sn.kdeplot(movie_stats.Budget_Millions,movie_stats.CriticsRatings,ax=ax[0,1])
k6=sn.kdeplot(movie_stats.Budget_Millions,movie_stats.Year,ax=ax[1,0])
k7=sn.kdeplot(movie_stats.AudienceRatings,movie_stats.CriticsRatings,ax=ax[1,1])
plt.show()
